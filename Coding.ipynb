# %%
#extra techs
#list comperhension  p.80, p.94
#enumerate p.83
#lambda
#localvar?
#heap p.447
#trie p.459
#gcd
#Backtracking
#dijkstras p.374

# %%
#Array
arr = [1, 3, 7, 12, 12, 16]

arr is None
'key' in arr
arr.count('key')
arr.index(12) #first occurence index / error if not found
del arr[0] #void, modifies original / remove at index
arr.remove(7) #void / remove value / error if value not in arr
arr.sort() #void, modifies original
arr.sort(key=lambda x: x)
sorted(arr) #returns
min(arr)
arr.reverse() #void, modifies original
arr.insert(0, 0) #void, modifies original
list(map(lambda x: x + 10, arr)) #to iterate list() is not needed / map(func, arr)
[n * 2 for n in arr if n % 2 == 0] #if is applied while before outputting
for ind, val in enumerate(arr):
    pass
import sys
maxint = sys.maxsize


#String
string = 'Hello123!'
list('hi!')
string.isalnum() #is alphabet or number
string.lower() #return lower cased string
string.split() #split by space and return array
string.replace("!", "")
''.join(['1', '2', '3']) #append strings toghether
#re.sub, replace, etc.


#Dict
#can use most operations used in arr, such as del
d = {'1': 1, '2': 2, '3': 3}

for key, val in d.items():
    pass
'key' in d

import collections
defd = collections.defaultdict(int)
defd['key'] #non-existent keys do not raise error

counter = collections.Counter(arr) #Counter({12: 2, 0: 1, 16: 1, 3: 1})
for val, count in counter.items():
    pass
counter.most_common(2) #array of tuples, 2 most common

#Sets
s = set([1, 2, 2])
s.add(5)
s.remove(1) #non-exting element will raise error

set() - set() #can add or sub sets


#stack
stack = []
stack.append(1)
stack.pop()


#queue / deque
import collections
d = collections.deque()
d.append(1)
d.appendleft(0) #O(1)
d.pop()
d.popleft() #O(1)


#relation to priority queue p.277
#further understanding of heapq
import heapq
heap = [0, 3, 1, 2]
heapq.heapify(heap) #convert to heap order if non-empty
heapq.heappush(heap, 5)
heapq.heappop(heap) #pops smallest element


#Linked List
class ListNode:
    def __init__(self, val=None, next=None):
        self.val = val
        self.next = next

head = ListNode(1, ListNode(2, ListNode(3, ListNode(4, ListNode(5)))))

slow = fast = head  #Fast slow method to take midpoint of linked list
while fast and fast.next:
    fast = fast.next.next
    slow = slow.next
slow.val #midpoint

def reverse(node, prev=None):
    if not node:
        return prev
    next, node.next = node.next, prev
    return reverse(next, node)

def reverse2(head):
    node = head
    prev = None
    while node:
        next = node.next
        node.next = prev
        prev = node
        node = next
    return prev


#Graphs
graph = {
    1: [2, 3, 4],
    2: [5],
    3: [5],
    4: [],
    5: [6,7],
    6: [],
    7: [3]
}

def recursive_dfs(v, discovered=[]):
    discovered.append(v)
    for w in graph[v]:
        if w not in discovered:
            discovered = recursive_dfs(w, discovered) #assigning to discovered for returning
    return discovered #showing result by returning

def iterative_dfs(start_v):
    discovered = []
    stack = [start_v]
    while stack:
        v = stack.pop()
        if v not in discovered:
            discovered.append(v)
            for w in graph[v]:
                stack.append(w)
    return discovered

import collections
def iterative_bfs(start_v):
    discovered = []
    d = collections.deque()
    d.append(start_v)
    while d:
        v = d.popleft()
        if v not in discovered:
            discovered.append(v)
            for w in graph[v]:
                d.append(w)
    return discovered

#more elegant but must add the first element when initializing the queue / stack (also applicable to DFS (stack))
import collections
def iterative_bfs(start_v):
    discovered = [start_v]
    d = collections.deque()
    d.append(start_v)
    while d:
        v = d.popleft()
        for w in graph[v]:
            if w not in discovered:
                discovered.append(w)
                d.append(w)
    return discovered


#Binary Tree
class Node:
    def __init__(self, val=None, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

root = Node('F', Node('B', Node('A'), Node('D', Node('C'), Node('E'))), Node('G', None, Node('I', Node('H'))))

def preorder(node):
    if node is None:
        return
    print(node.val)
    preorder(node.left)
    preorder(node.right)

def inorder(node):
    if node is None:
        return
    inorder(node.left)
    print(node.val)
    inorder(node.right)

def postorder(node):
    if node is None:
        return
    postorder(node.left)
    postorder(node.right)
    print(node.val)
